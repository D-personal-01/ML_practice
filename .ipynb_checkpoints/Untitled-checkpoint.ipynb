# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("anaconda_projects\ML\.ipynb_checkpoints\sample_placement_1000x4.csv")
# Out:
#   Cell In[2], line 1
#     df=pd.read_csv("C:\Users\Lenovo\anaconda_projects\ML\.ipynb_checkpoints\sample_placement_1000x4.csv")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.head()

# %%
df.shape

# %%
print(df)

# %%
df=df.iloc[:,1:]

# %%
df.shape

# %%
print(df)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["CGPA"],df["IQ"],c=df["Placement"])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test= tts(x,y,test_size=0.50, random_state=0)

# %%
x_train

# %%
x_train.shape

# %%
from sklearn.preprocessing import StandardScaler as ss

# %%
scaler=ss()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train

# %%
x_test=scaler.transform(x_test)

# %%
x_test

# %%
plt.scatter(df["CGPA"],df["IQ"],c=df["Placement"])

# %%
from sklearn.linear_model import LogisticRegression as lr

# %%
clf=lr()

# %%
clf.fit(x_train,y_train)

# %%
y_p=clf.predict(x_test)

# %%
y_p

# %%
y_test

# %%
from sklearn.metrics import accuracy_score as ays

# %%
ays(y_test,y_p)

# %%
# !pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions as pdr

# %%
pdr(x_train, y_train.values, clf=clf, legend=2)

# %%
import pickle

# %%
pickle.dump(clf)
